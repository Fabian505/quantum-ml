# %%
# !pip install qiskit-ibm-runtime --break-system-packages
# Out:
# Requirement already satisfied: qiskit-ibm-runtime in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (0.29.0)
# Requirement already satisfied: requests>=2.19 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from qiskit-ibm-runtime) (2.33.1)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: numpy>=1.13 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from qiskit-ibm-runtime) (2.4.4)
# Requirement already satisfied: urllib3>=1.21.1 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from qiskit-ibm-runtime) (2.6.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Requirement already satisfied: websocket-client>=1.5.1 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from qiskit-ibm-runtime) (1.9.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from qiskit-ibm-runtime) (0.75.0)
# Requirement already satisfied: pydantic>=2.5.0 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from qiskit-ibm-runtime) (2.13.3)
# Requirement already satisfied: qiskit>=1.1.0 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from qiskit-ibm-runtime) (2.4.1)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.4 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (3.24.4)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (2.12.1)
# Requirement already satisfied: six>=1.5 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.13)
# Requirement already satisfied: certifi>=2023.5.7 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibm-runtime) (2026.4.22)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (2.46.3)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: rustworkx>=0.15.0 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-ibm-runtime) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-ibm-runtime) (1.17.1)
# Requirement already satisfied: dill>=0.3 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-ibm-runtime) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-ibm-runtime) (5.7.0)
# Requirement already satisfied: cryptography>=1.3 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (47.0.0)
# Requirement already satisfied: pyspnego>=0.4.0 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.12.1)
# Requirement already satisfied: cffi>=2.0.0 in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Requirement already satisfied: pycparser in /home/fabian/anaconda3/envs/qml/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (3.0)

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(channel="ibm_quantum_platform", token="DEIN_TOKEN")
print(service._all_instances)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from qiskit_ibm_runtime import QiskitRuntimeService
#       2
#       3 QiskitRuntimeService.save_account(
#       4     channel="ibm_quantum_platform",
#
# File ~/anaconda3/envs/qml/lib/python3.11/site-packages/qiskit_ibm_runtime/__init__.py:204
#     201 import logging
#     202 import warnings
# --> 204 from .qiskit_runtime_service import QiskitRuntimeService
#     205 from .ibm_backend import IBMBackend
#     206 from .runtime_job import RuntimeJob
#
# File ~/anaconda3/envs/qml/lib/python3.11/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:27
#      24 from qiskit.providers.exceptions import QiskitBackendNotFoundError
#      25 from qiskit.providers.providerutils import filter_backends
# ---> 27 from qiskit_ibm_runtime import ibm_backend
#      28 from .proxies import ProxyConfiguration
#      29 from .utils.deprecation import issue_deprecation_msg, deprecate_function
#
# File ~/anaconda3/envs/qml/lib/python3.11/site-packages/qiskit_ibm_runtime/ibm_backend.py:23
#      20 import warnings
#      22 from qiskit import QuantumCircuit
# ---> 23 from qiskit.qobj.utils import MeasLevel, MeasReturnType
#      25 from qiskit.providers.backend import BackendV2 as Backend
#      26 from qiskit.providers.options import Options
#
# ModuleNotFoundError: No module named 'qiskit.qobj'

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_ibm_runtime import SamplerV2 as Sampler, QiskitRuntimeService

# Circuit bauen
qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure([0, 1], [0, 1])

# Verbinden
service = QiskitRuntimeService()
backend = service.backend("ibm_kingston")

# Transpilieren (auf Backend-native Gates übersetzen)
qc_transpiled = transpile(qc, backend=backend)

# Job abschicken
sampler = Sampler(backend)
job = sampler.run([qc_transpiled], shots=1024)

print("Job ID:", job.job_id())
print("Status:", job.status())
# Out:
# qiskit_runtime_service.__init__:WARNING:2026-04-27 22:21:45,010: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# qiskit_runtime_service.backends:WARNING:2026-04-27 22:21:45,012: Using instance: open-instance, plan: open
# Job ID: d7nsan497osc73dsfbr0
# Status: RUNNING

# %%
# Ergebnis abrufen (blockiert bis Job fertig ist)
result = job.result()

# Counts auslesen
counts = result[0].data.c.get_counts()
print("Ergebnisse:", counts)
# Out:
# Ergebnisse: {'00': 499, '11': 514, '10': 7, '01': 4}
